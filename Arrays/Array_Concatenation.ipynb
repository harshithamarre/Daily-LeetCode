# %%
# Arrays: (LC 1929)
# Problem Link: https://leetcode.com/problems/concatenation-of-array

nums = list(map(int,input("Enter array of integers: ").split(",")))

print(nums*2)
# Out:
# Enter array of integers:  1,3,1
# [1, 3, 1, 1, 3, 1]
