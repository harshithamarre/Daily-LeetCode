# %%
# LC 3740
# Problem Link: https://leetcode.com/problems/minimum-distance-between-three-equal-elements-i

nums = list(map(int,input("Enter array of integers: ").split(",")))
good = []
distances = []

for i in range(len(nums)):
    for j in range(i+1,len(nums)):
        for k in range(j+1,len(nums)):
            if nums[i] == nums[j] == nums[k]:
                good.append([i,j,k])

for tup in good:
    dist = abs(tup[0] - tup[1]) + abs(tup[1] - tup[2]) + abs(tup[2] - tup[0])
    distances.append(dist)

print(min(distances))
# Out:
# Enter array of integers:  1,1,2,3,2,1,2
# 8
